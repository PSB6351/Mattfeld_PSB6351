# %% [markdown]
# # I will use the following notebook to demonstrate different steps in preprocessing
#
# ## These steps will include:
#
# ### 1) Slice timing correction
# ### 2) Motion correction

# %%
import os
from glob import glob

# Import new things that we'll need
import pandas as pd
import numpy as np
import nipype.interfaces.afni as afni
import nipype.interfaces.fsl as fsl
import nipype.interfaces.freesurfer as fs
from nipype.interfaces.utility import Function
import seaborn as sns
import nibabel as nb
import json
import nipype.interfaces.io as nio
import nipype.pipeline.engine as pe 
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### I next want to get a list of all of my functional files

# %%
sid = ['021']
base_dir = '/home/nmatt015/Mattfeld_PSB6351/'
work_dir = '/scratch/madlab/Mattfeld_PSB6351/nmatt015/'
func_dir = os.path.join(base_dir, f'dset/sub-{sid[0]}/func')
fmap_dir = os.path.join(base_dir, f'dset/sub-{sid[0]}/fmap')
fs_dir = os.path.join(base_dir, 'derivatives', 'freesurfer')

# Get a list of my study task json and nifti converted files
func_json = sorted(glob(func_dir + '/*.json'))
func_files = sorted(glob(func_dir + '/*.nii.gz'))
fmap_files = sorted(glob(fmap_dir + '/*func*.nii.gz'))

# %%
func_files[0]
# Out:
# '/home/nmatt015/Mattfeld_PSB6351/dset/sub-021/func/sub-021_task-loc_run-1_bold.nii.gz'

# %%
func_dir
# Out:
# '/home/nmatt015/Mattfeld_PSB6351/dset/sub-021/func'

# %% [markdown]
# ### Next I want to build and run function to perform slice timing correction. I'm going to have to extract some important information from the .json files like the multiband slicetiming.

# %%
os.environ['PATH'] += ':/home/applications/fsl/6.0.6/bin'
# !which fslroi
# Out:
# /home/applications/fsl/6.0.6/bin/fslroi

# %%
ls /home/nmatt015/Mattfeld_PSB6351/dset/sub-021/anat
# Out:
# sub-021_run-1_T1w.json    sub-021_run-2_T1w.json
# sub-021_run-1_T1w.nii.gz  sub-021_run-2_T1w.nii.gz

# %%
# Here I am building a function that eliminates the
# mapnode directory structure and assists in saving
# all of the outputs into a single directory
def get_subs(func_files):
    '''Produces Name Substitutions for Each Contrast'''
    subs = []
    for curr_run in range(len(func_files)):
        subs.append(('_tshifter%d' %curr_run, ''))
        subs.append(('_volreg%d' %curr_run, ''))
    return subs

# Here I am building a function that takes in a
# text file that includes the number of outliers
# at each volume and then finds which volume (e.g., index)
# has the minimum number of outliers (e.g., min) 
# searching over the first 201 volumes
# If the index function returns a list because there were
# multiple volumes with the same outlier count, pick the first one

# HW3 - change the search window. how does this impact your results?
def best_vol(outlier_count):
    best_vol_num = outlier_count.index(min(outlier_count[:200]))
    if isinstance(best_vol_num, list):
        best_vol_num = best_vol_num[0]
    return best_vol_num

# Here I am creating a list of lists containing the slice timing for each study run
####################################
# HW3 - what column do you query to extract the appropriate information?
####################################
slice_timing_list = []
for curr_json in func_json:
    curr_json_data = open(curr_json)
    curr_func_metadata = json.load(curr_json_data)
    slice_timing_list.append(curr_func_metadata['SliceTiming'])

# Here I am establishing a nipype work flow that I will eventually execute
psb6351_wf = pe.Workflow(name='psb6351_wf')
psb6351_wf.base_dir = work_dir + f'/psb6351workdir/sub-{sid[0]}'
psb6351_wf.config['execution']['use_relative_paths'] = True

# Create a Function node to substitute names of files created during pipeline
getsubs = pe.Node(Function(input_names=['func_files'],
                           output_names=['subs'],
                           function=get_subs),
                  name='getsubs')
getsubs.inputs.func_files = func_files

# Here I am inputing just the first run functional data
# I want to use afni's 3dToutcount to find the number of 
# outliers at each volume.  I will use this information to
# later select the earliest volume with the least number of outliers
# to serve as the base for the motion correction
id_outliers = pe.Node(afni.OutlierCount(),
                      name = 'id_outliers')
####################################
# HW3 - what happens if you chose a different func_file?  How does it impact results
# Is the first func file the best way to go?
####################################
id_outliers.inputs.in_file = func_files[0]
id_outliers.inputs.automask = True
id_outliers.inputs.out_file = 'outlier_file'

# Create a Function node to identify the best volume based
# on the number of outliers at each volume. I'm searching
# for the index in the first 201 volumes that has the 
# minimum number of outliers and will use the min() function
# I will use the index function to get the best vol. 
getbestvol = pe.Node(Function(input_names=['outlier_count'],
                              output_names=['best_vol_num'],
                              function=best_vol),
                     name='getbestvol')
psb6351_wf.connect(id_outliers, 'out_file', getbestvol, 'outlier_count')

# Extract the earliest volume with the
# the fewest outliers of the first run as the reference 
extractref = pe.Node(fsl.ExtractROI(t_size=1),
                     name = "extractref")
####################################
# HW3 - if you choose a different func file...should this change too?
# If yes, why?  what should it change to?
####################################
extractref.inputs.in_file = func_files[0]
psb6351_wf.connect(getbestvol, 'best_vol_num', extractref, 't_min')

# Below is the command that runs AFNI's 3dvolreg command.
# this is the node that performs the motion correction
# I'm iterating over the functional files which I am passing
# functional data from the slice timing correction node before
# I'm using the earliest volume with the least number of outliers
# during the first run as the base file to register to.

####################################
# HW3 - what happens when you change the order of the following two nodes?
# How does that impact your results?
# Run things again with the order reversed and save in a new sink folder without deleting your first
####################################
volreg1st = pe.MapNode(afni.Volreg(),
                    iterfield=['in_file'],
                    name = 'volreg1st')
volreg1st.inputs.outputtype = 'NIFTI_GZ'
volreg1st.inputs.zpad = 4
volreg1st.inputs.in_file = func_files
psb6351_wf.connect(extractref, 'roi_file', volreg1st, 'basefile')

mcflirt1st = pe.MapNode(fsl.MCFLIRT(),
                    iterfield=['in_file'],
                    name = 'mcflirt1st')
mcflirt1st.inputs.output_type = 'NIFTI_GZ'
mcflirt1st.inputs.in_file = func_files
psb6351_wf.connect(extractref, 'roi_file', mcflirt1st, 'ref_file')

# Below is the command that runs AFNI's 3dTshift command
# this is the node that performs the slice timing correction
# I input the study func files as a list and the slice timing 
# as a list of lists. I'm using a MapNode to iterate over the two.
# this should allow me to parallelize this on the HPC
tshifter2nd = pe.MapNode(afni.TShift(),
                      iterfield=['in_file','slice_timing'],
                      name = 'tshifter2nd')
tshifter2nd.inputs.tr = '1.76'
tshifter2nd.inputs.slice_timing = slice_timing_list
tshifter2nd.inputs.outputtype = 'NIFTI_GZ'
psb6351_wf.connect(volreg1st, 'out_file', tshifter2nd, 'in_file')

tshifter1st = pe.MapNode(afni.TShift(),
                      iterfield=['in_file','slice_timing'],
                      name = 'tshifter1st')
tshifter1st.inputs.tr = '1.76'
tshifter1st.inputs.slice_timing = slice_timing_list
tshifter1st.inputs.outputtype = 'NIFTI_GZ'
tshifter1st.inputs.in_file = func_files

volreg2nd = pe.MapNode(afni.Volreg(),
                    iterfield=['in_file'],
                    name = 'volreg2nd')
volreg2nd.inputs.outputtype = 'NIFTI_GZ'
volreg2nd.inputs.zpad = 4
psb6351_wf.connect(extractref, 'roi_file', volreg2nd, 'basefile')
psb6351_wf.connect(tshifter1st, 'out_file', volreg2nd, 'in_file')

# HW4 Add a coregistration node to coregister functional to structural
# make sure to connect node appropriately and to sink the data
# in the datasink below appropriately...required...sink the transformation matrix

coregister = pe.MapNode(fsl.FLIRT(),
                        iterfield=['in_file'], 
                        name='coregister')
coregister.inputs.output_type = 'NIFTI_GZ'
coregister.inputs.dof = 6

coregister.inputs.reference = '/home/nmatt015/Mattfeld_PSB6351/dset/sub-021/anat/sub-021_run-1_T1w.nii.gz'

# Below is the node that collects all the data and saves
# the outputs that I am interested in. Here in this node
# I use the substitutions input combined with the earlier
# function to get rid of nesting
datasink = pe.Node(nio.DataSink(), name="datasink")
datasink.inputs.base_directory = os.path.join(base_dir, 'derivatives/preproc')
datasink.inputs.container = f'sub-{sid[0]}'
psb6351_wf.connect(tshifter2nd, 'out_file', datasink, 'sltime_corr2nd')
psb6351_wf.connect(extractref, 'roi_file', datasink, 'study_ref')
psb6351_wf.connect(volreg1st, 'out_file', datasink, 'motion1stAFNI.@corrfile')
psb6351_wf.connect(volreg1st, 'oned_matrix_save', datasink, 'motion1stAFNI.@matrix')
psb6351_wf.connect(volreg1st, 'oned_file', datasink, 'motion1stAFNI.@par')
psb6351_wf.connect(getsubs, 'subs', datasink, 'substitutions')

psb6351_wf.connect(mcflirt1st, 'mat_file', datasink, 'motion1stFSL.@matrix')
psb6351_wf.connect(mcflirt1st, 'par_file', datasink, 'motion1stFSL.@par')
psb6351_wf.connect(mcflirt1st, 'out_file', datasink, 'motion1stFSL.@corrfile')

psb6351_wf.connect(tshifter1st, 'out_file', datasink, 'sltime_corr1st')
psb6351_wf.connect(volreg2nd, 'out_file', datasink, 'motionn2nd.@corrfile')
psb6351_wf.connect(volreg2nd, 'oned_matrix_save', datasink, 'motion2nd.@matrix')
psb6351_wf.connect(volreg2nd, 'oned_file', datasink, 'motion2nd.@par')

psb6351_wf.connect(volreg1st, 'out_file', coregister, 'in_file')
psb6351_wf.connect(coregister, 'out_file', datasink, 'coregistration.@registered_func')
psb6351_wf.connect(coregister, 'out_matrix_file', datasink, 'coregistration.@transform_matrix')

# The following lines set a work directory outside of my 
# local git repo and runs the workflow
psb6351_wf.run()
#psb6351_wf.run(plugin='SLURM',
#               plugin_args={'sbatch_args': ('--partition IB_44C_512G --qos pq_madlab --account acc_madlab'),
#                            'overwrite':True})
# Out:
# 241017-17:07:16,194 nipype.interface WARNING:
# 	 FSLOUTPUTTYPE environment variable is not set. Setting FSLOUTPUTTYPE=NIFTI
# 241017-17:07:16,204 nipype.interface WARNING:
# 	 FSLOUTPUTTYPE environment variable is not set. Setting FSLOUTPUTTYPE=NIFTI
# 241017-17:07:16,221 nipype.interface WARNING:
# 	 FSLOUTPUTTYPE environment variable is not set. Setting FSLOUTPUTTYPE=NIFTI
# 241017-17:07:16,246 nipype.workflow INFO:
# 	 Workflow psb6351_wf settings: ['check', 'execution', 'logging', 'monitoring']
# 241017-17:07:16,334 nipype.workflow INFO:
# 	 Running serially.
# 241017-17:07:16,335 nipype.workflow INFO:
# 	 [Node] Setting-up "psb6351_wf.id_outliers" in "/scratch/madlab/Mattfeld_PSB6351/nmatt015/psb6351workdir/sub-021/psb6351_wf/id_outliers".
# 241017-17:07:16,353 nipype.workflow INFO:
# 	 [Node] Cached "psb6351_wf.id_outliers" - collecting precomputed outputs
# 241017-17:07:16,354 nipype.workflow INFO:
# 	 [Node] "psb6351_wf.id_outliers" found cached.
# 241017-17:07:16,370 nipype.workflow INFO:
# 	 [Node] "psb6351_wf.tshifter1st" found cached.
# 241017-17:07:16,372 nipype.workflow INFO:
# 	 [Node] Setting-up "psb6351_wf.getsubs" in "/scratch/madlab/Mattfeld_PSB6351/nmatt015/psb6351workdir/sub-021/psb6351_wf/getsubs".
# 241017-17:07:16,377 nipype.workflow INFO:
# 	 [Node] Cached "psb6351_wf.getsubs" - collecting precomputed outputs
# 241017-17:07:16,378 nipype.workflow INFO:
# 	 [Node] "psb6351_wf.getsubs" found cached.
# 241017-17:07:16,379 nipype.workflow INFO:
# 	 [Node] Setting-up "psb6351_wf.getbestvol" in "/scratch/madlab/Mattfeld_PSB6351/nmatt015/psb6351workdir/sub-021/psb6351_wf/getbestvol".
# 241017-17:07:16,386 nipype.workflow INFO:
# 	 [Node] Cached "psb6351_wf.getbestvol" - collecting precomputed outputs
# 241017-17:07:16,387 nipype.workflow INFO:
# 	 [Node] "psb6351_wf.getbestvol" found cached.
# 241017-17:07:16,388 nipype.workflow INFO:
# 	 [Node] Setting-up "psb6351_wf.extractref" in "/scratch/madlab/Mattfeld_PSB6351/nmatt015/psb6351workdir/sub-021/psb6351_wf/extractref".
# 241017-17:07:16,395 nipype.workflow INFO:
# 	 [Node] Cached "psb6351_wf.extractref" - collecting precomputed outputs
# 241017-17:07:16,396 nipype.workflow INFO:
# 	 [Node] "psb6351_wf.extractref" found cached.
# 241017-17:07:16,408 nipype.workflow INFO:
# 	 [Node] "psb6351_wf.volreg1st" found cached.
# 241017-17:07:16,420 nipype.workflow INFO:
# 	 [Node] "psb6351_wf.mcflirt1st" found cached.
# 241017-17:07:16,434 nipype.workflow INFO:
# 	 [Node] "psb6351_wf.volreg2nd" found cached.
# 241017-17:07:16,451 nipype.workflow INFO:
# 	 [Node] "psb6351_wf.tshifter2nd" found cached.
# 241017-17:07:16,487 nipype.workflow INFO:
# 	 [Node] Setting-up "_coregister0" in "/scratch/madlab/Mattfeld_PSB6351/nmatt015/psb6351workdir/sub-021/psb6351_wf/coregister/mapflow/_coregister0".
# 241017-17:07:16,509 nipype.workflow INFO:
# 	 [Node] Executing "_coregister0" <nipype.interfaces.fsl.preprocess.FLIRT>
# 241017-17:07:23,67 nipype.interface INFO:
# 	 stderr 2024-10-17T17:07:23.067294:Warning: An input intended to be a single 3D volume has multiple timepoints. Input will be truncated to first volume, but this functionality is deprecated and will be removed in a future release.
# 241017-17:07:37,272 nipype.interface INFO:
# 	 stderr 2024-10-17T17:07:37.271989:Warning: An input intended to be a single 3D volume has multiple timepoints. Input will be truncated to first volume, but this functionality is deprecated and will be removed in a future release.
# 241017-17:07:40,830 nipype.workflow INFO:
# 	 [Node] Finished "_coregister0", elapsed time 24.228347s.
# 241017-17:07:40,923 nipype.workflow INFO:
# 	 [Node] Setting-up "_coregister1" in "/scratch/madlab/Mattfeld_PSB6351/nmatt015/psb6351workdir/sub-021/psb6351_wf/coregister/mapflow/_coregister1".
# 241017-17:07:40,974 nipype.workflow INFO:
# 	 [Node] Executing "_coregister1" <nipype.interfaces.fsl.preprocess.FLIRT>
# 241017-17:07:46,567 nipype.interface INFO:
# 	 stderr 2024-10-17T17:07:46.567153:Warning: An input intended to be a single 3D volume has multiple timepoints. Input will be truncated to first volume, but this functionality is deprecated and will be removed in a future release.
# 241017-17:08:00,177 nipype.interface INFO:
# 	 stderr 2024-10-17T17:08:00.176741:Warning: An input intended to be a single 3D volume has multiple timepoints. Input will be truncated to first volume, but this functionality is deprecated and will be removed in a future release.
# 241017-17:08:03,934 nipype.workflow INFO:
# 	 [Node] Finished "_coregister1", elapsed time 22.870204s.
# 241017-17:08:04,28 nipype.workflow INFO:
# 	 [Node] Setting-up "_coregister2" in "/scratch/madlab/Mattfeld_PSB6351/nmatt015/psb6351workdir/sub-021/psb6351_wf/coregister/mapflow/_coregister2".
# 241017-17:08:04,54 nipype.workflow INFO:
# 	 [Node] Executing "_coregister2" <nipype.interfaces.fsl.preprocess.FLIRT>
# 241017-17:08:10,133 nipype.interface INFO:
# 	 stderr 2024-10-17T17:08:10.117764:Warning: An input intended to be a single 3D volume has multiple timepoints. Input will be truncated to first volume, but this functionality is deprecated and will be removed in a future release.
# 241017-17:08:24,263 nipype.interface INFO:
# 	 stderr 2024-10-17T17:08:24.262331:Warning: An input intended to be a single 3D volume has multiple timepoints. Input will be truncated to first volume, but this functionality is deprecated and will be removed in a future release.
# 241017-17:08:27,716 nipype.workflow INFO:
# 	 [Node] Finished "_coregister2", elapsed time 23.653793s.
# 241017-17:08:27,793 nipype.workflow INFO:
# 	 [Node] Setting-up "_coregister3" in "/scratch/madlab/Mattfeld_PSB6351/nmatt015/psb6351workdir/sub-021/psb6351_wf/coregister/mapflow/_coregister3".
# 241017-17:08:27,818 nipype.workflow INFO:
# 	 [Node] Executing "_coregister3" <nipype.interfaces.fsl.preprocess.FLIRT>
# 241017-17:08:33,984 nipype.interface INFO:
# 	 stderr 2024-10-17T17:08:33.984417:Warning: An input intended to be a single 3D volume has multiple timepoints. Input will be truncated to first volume, but this functionality is deprecated and will be removed in a future release.
# 241017-17:08:48,188 nipype.interface INFO:
# 	 stderr 2024-10-17T17:08:48.187937:Warning: An input intended to be a single 3D volume has multiple timepoints. Input will be truncated to first volume, but this functionality is deprecated and will be removed in a future release.
# 241017-17:08:51,760 nipype.workflow INFO:
# 	 [Node] Finished "_coregister3", elapsed time 23.911567s.
# 241017-17:08:51,877 nipype.workflow INFO:
# 	 [Node] Setting-up "_coregister4" in "/scratch/madlab/Mattfeld_PSB6351/nmatt015/psb6351workdir/sub-021/psb6351_wf/coregister/mapflow/_coregister4".
# 241017-17:08:51,903 nipype.workflow INFO:
# 	 [Node] Executing "_coregister4" <nipype.interfaces.fsl.preprocess.FLIRT>
# 241017-17:08:57,884 nipype.interface INFO:
# 	 stderr 2024-10-17T17:08:57.884559:Warning: An input intended to be a single 3D volume has multiple timepoints. Input will be truncated to first volume, but this functionality is deprecated and will be removed in a future release.
# 241017-17:09:12,356 nipype.interface INFO:
# 	 stderr 2024-10-17T17:09:12.355963:Warning: An input intended to be a single 3D volume has multiple timepoints. Input will be truncated to first volume, but this functionality is deprecated and will be removed in a future release.
# 241017-17:09:15,791 nipype.workflow INFO:
# 	 [Node] Finished "_coregister4", elapsed time 23.792546s.
# 241017-17:09:15,901 nipype.workflow INFO:
# 	 [Node] Setting-up "psb6351_wf.datasink" in "/scratch/madlab/Mattfeld_PSB6351/nmatt015/psb6351workdir/sub-021/psb6351_wf/datasink".
# 241017-17:09:16,8 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "psb6351_wf.datasink".
# 241017-17:09:16,45 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 241017-17:09:16,49 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/sltime_corr2nd/_tshifter2nd0/sub-021_task-loc_run-1_bold_volreg_tshift.nii.gz -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/sltime_corr2nd/nd0/sub-021_task-loc_run-1_bold_volreg_tshift.nii.gz
# 241017-17:09:18,240 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/sltime_corr2nd/_tshifter2nd1/sub-021_task-loc_run-2_bold_volreg_tshift.nii.gz -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/sltime_corr2nd/nd1/sub-021_task-loc_run-2_bold_volreg_tshift.nii.gz
# 241017-17:09:20,711 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/sltime_corr2nd/_tshifter2nd2/sub-021_task-study_run-2_bold_volreg_tshift.nii.gz -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/sltime_corr2nd/nd2/sub-021_task-study_run-2_bold_volreg_tshift.nii.gz
# 241017-17:09:23,270 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/sltime_corr2nd/_tshifter2nd3/sub-021_task-study_run-3_bold_volreg_tshift.nii.gz -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/sltime_corr2nd/nd3/sub-021_task-study_run-3_bold_volreg_tshift.nii.gz
# 241017-17:09:25,735 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/sltime_corr2nd/_tshifter2nd4/sub-021_task-study_run-4_bold_volreg_tshift.nii.gz -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/sltime_corr2nd/nd4/sub-021_task-study_run-4_bold_volreg_tshift.nii.gz
# 241017-17:09:28,330 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion1stAFNI/_volreg1st0/sub-021_task-loc_run-1_bold_volreg.nii.gz -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion1stAFNI/st0/sub-021_task-loc_run-1_bold_volreg.nii.gz
# 241017-17:09:30,87 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion1stAFNI/_volreg1st1/sub-021_task-loc_run-2_bold_volreg.nii.gz -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion1stAFNI/st1/sub-021_task-loc_run-2_bold_volreg.nii.gz
# 241017-17:09:32,122 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion1stAFNI/_volreg1st2/sub-021_task-study_run-2_bold_volreg.nii.gz -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion1stAFNI/st2/sub-021_task-study_run-2_bold_volreg.nii.gz
# 241017-17:09:34,207 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion1stAFNI/_volreg1st3/sub-021_task-study_run-3_bold_volreg.nii.gz -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion1stAFNI/st3/sub-021_task-study_run-3_bold_volreg.nii.gz
# 241017-17:09:36,307 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion1stAFNI/_volreg1st4/sub-021_task-study_run-4_bold_volreg.nii.gz -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion1stAFNI/st4/sub-021_task-study_run-4_bold_volreg.nii.gz
# 241017-17:09:38,264 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion1stAFNI/_volreg1st0/sub-021_task-loc_run-1_bold.aff12.1D -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion1stAFNI/st0/sub-021_task-loc_run-1_bold.aff12.1D
# 241017-17:09:38,382 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion1stAFNI/_volreg1st1/sub-021_task-loc_run-2_bold.aff12.1D -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion1stAFNI/st1/sub-021_task-loc_run-2_bold.aff12.1D
# 241017-17:09:38,458 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion1stAFNI/_volreg1st2/sub-021_task-study_run-2_bold.aff12.1D -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion1stAFNI/st2/sub-021_task-study_run-2_bold.aff12.1D
# 241017-17:09:38,480 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion1stAFNI/_volreg1st3/sub-021_task-study_run-3_bold.aff12.1D -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion1stAFNI/st3/sub-021_task-study_run-3_bold.aff12.1D
# 241017-17:09:38,500 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion1stAFNI/_volreg1st4/sub-021_task-study_run-4_bold.aff12.1D -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion1stAFNI/st4/sub-021_task-study_run-4_bold.aff12.1D
# 241017-17:09:38,534 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion1stAFNI/_volreg1st0/sub-021_task-loc_run-1_bold.1D -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion1stAFNI/st0/sub-021_task-loc_run-1_bold.1D
# 241017-17:09:38,725 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion1stAFNI/_volreg1st1/sub-021_task-loc_run-2_bold.1D -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion1stAFNI/st1/sub-021_task-loc_run-2_bold.1D
# 241017-17:09:38,757 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion1stAFNI/_volreg1st2/sub-021_task-study_run-2_bold.1D -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion1stAFNI/st2/sub-021_task-study_run-2_bold.1D
# 241017-17:09:38,879 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion1stAFNI/_volreg1st3/sub-021_task-study_run-3_bold.1D -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion1stAFNI/st3/sub-021_task-study_run-3_bold.1D
# 241017-17:09:38,916 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion1stAFNI/_volreg1st4/sub-021_task-study_run-4_bold.1D -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion1stAFNI/st4/sub-021_task-study_run-4_bold.1D
# 241017-17:09:50,74 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/sltime_corr1st/_tshifter1st0/sub-021_task-loc_run-1_bold_tshift.nii.gz -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/sltime_corr1st/st0/sub-021_task-loc_run-1_bold_tshift.nii.gz
# 241017-17:09:52,194 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/sltime_corr1st/_tshifter1st1/sub-021_task-loc_run-2_bold_tshift.nii.gz -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/sltime_corr1st/st1/sub-021_task-loc_run-2_bold_tshift.nii.gz
# 241017-17:09:54,385 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/sltime_corr1st/_tshifter1st2/sub-021_task-study_run-2_bold_tshift.nii.gz -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/sltime_corr1st/st2/sub-021_task-study_run-2_bold_tshift.nii.gz
# 241017-17:09:57,195 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/sltime_corr1st/_tshifter1st3/sub-021_task-study_run-3_bold_tshift.nii.gz -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/sltime_corr1st/st3/sub-021_task-study_run-3_bold_tshift.nii.gz
# 241017-17:09:59,635 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/sltime_corr1st/_tshifter1st4/sub-021_task-study_run-4_bold_tshift.nii.gz -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/sltime_corr1st/st4/sub-021_task-study_run-4_bold_tshift.nii.gz
# 241017-17:10:02,426 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motionn2nd/_volreg2nd0/sub-021_task-loc_run-1_bold_tshift_volreg.nii.gz -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motionn2nd/nd0/sub-021_task-loc_run-1_bold_tshift_volreg.nii.gz
# 241017-17:10:04,663 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motionn2nd/_volreg2nd1/sub-021_task-loc_run-2_bold_tshift_volreg.nii.gz -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motionn2nd/nd1/sub-021_task-loc_run-2_bold_tshift_volreg.nii.gz
# 241017-17:10:07,61 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motionn2nd/_volreg2nd2/sub-021_task-study_run-2_bold_tshift_volreg.nii.gz -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motionn2nd/nd2/sub-021_task-study_run-2_bold_tshift_volreg.nii.gz
# 241017-17:10:09,367 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motionn2nd/_volreg2nd3/sub-021_task-study_run-3_bold_tshift_volreg.nii.gz -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motionn2nd/nd3/sub-021_task-study_run-3_bold_tshift_volreg.nii.gz
# 241017-17:10:11,947 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motionn2nd/_volreg2nd4/sub-021_task-study_run-4_bold_tshift_volreg.nii.gz -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motionn2nd/nd4/sub-021_task-study_run-4_bold_tshift_volreg.nii.gz
# 241017-17:10:14,690 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion2nd/_volreg2nd0/sub-021_task-loc_run-1_bold_tshift.aff12.1D -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion2nd/nd0/sub-021_task-loc_run-1_bold_tshift.aff12.1D
# 241017-17:10:14,731 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion2nd/_volreg2nd1/sub-021_task-loc_run-2_bold_tshift.aff12.1D -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion2nd/nd1/sub-021_task-loc_run-2_bold_tshift.aff12.1D
# 241017-17:10:14,813 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion2nd/_volreg2nd2/sub-021_task-study_run-2_bold_tshift.aff12.1D -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion2nd/nd2/sub-021_task-study_run-2_bold_tshift.aff12.1D
# 241017-17:10:14,849 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion2nd/_volreg2nd3/sub-021_task-study_run-3_bold_tshift.aff12.1D -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion2nd/nd3/sub-021_task-study_run-3_bold_tshift.aff12.1D
# 241017-17:10:15,35 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion2nd/_volreg2nd4/sub-021_task-study_run-4_bold_tshift.aff12.1D -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion2nd/nd4/sub-021_task-study_run-4_bold_tshift.aff12.1D
# 241017-17:10:15,69 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion2nd/_volreg2nd0/sub-021_task-loc_run-1_bold_tshift.1D -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion2nd/nd0/sub-021_task-loc_run-1_bold_tshift.1D
# 241017-17:10:15,98 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion2nd/_volreg2nd1/sub-021_task-loc_run-2_bold_tshift.1D -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion2nd/nd1/sub-021_task-loc_run-2_bold_tshift.1D
# 241017-17:10:15,182 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion2nd/_volreg2nd2/sub-021_task-study_run-2_bold_tshift.1D -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion2nd/nd2/sub-021_task-study_run-2_bold_tshift.1D
# 241017-17:10:15,251 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion2nd/_volreg2nd3/sub-021_task-study_run-3_bold_tshift.1D -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion2nd/nd3/sub-021_task-study_run-3_bold_tshift.1D
# 241017-17:10:15,271 nipype.interface INFO:
# 	 sub: /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion2nd/_volreg2nd4/sub-021_task-study_run-4_bold_tshift.1D -> /home/nmatt015/Mattfeld_PSB6351/derivatives/preproc/sub-021/motion2nd/nd4/sub-021_task-study_run-4_bold_tshift.1D
# 241017-17:10:15,859 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 59.810083s.

# %% [markdown]
# ### Now I will load and plot the motion files

# %%
motion_dir = os.path.join(base_dir, f'derivatives/preproc/sub-{sid[0]}/motion')
study_motion_files = sorted(glob(motion_dir + '/*_bold.1D'))

for curr_mot_file in study_motion_files:
    # Read the motion parameters into a dataframe
    motion_df = pd.read_csv(curr_mot_file, sep="  ", header=None, engine='python')
    motion_df.columns = ['roll', 'pitch', 'yaw', 'dS', 'dL', 'dP']
    # Roll- rotation around the x axis
    # Pitch- rotation around the y axis
    # Yaw- rotation around the z axis
    # dS = displacement along superior inferior axis
    # dS- translation along the z axis
    # dL = displacement along the left right axis
    # dL- translation along the x axis
    # dP = displacement along the anterior posterior axis
    # dP- translation along the y axis

    # Prepare the figure and axes for plotting
    num_vols = range(1, len(motion_df) + 1)
    fig, axs = plt.subplots(motion_df.shape[1], 1, figsize=(15, 10))
    fig.subplots_adjust(hspace=0.3)  # Reduce space between plots

    # Change the colors so each parameter is unique
    colors = ['#FF0000', '#FF7F00', '#FFD700', '#00FF00', '#0000FF', '#8B00FF'] 

    # Plot each motion parameter
    for idx, (curr_col, color) in enumerate(zip(motion_df.columns, colors)):
        axs[idx].plot(num_vols, motion_df[curr_col], color=color, linewidth=1.5)
        axs[idx].set_ylabel(f'{curr_col}', fontsize=12)
        axs[idx].grid(True)

    # Set the x-axis label for the last subplot only, reads a bit easier 
    axs[-1].set_xlabel('Time (TRs)', fontsize=12)

    # Add a title for the entire figure
    fig.suptitle('Motion Parameters Across TRs', fontsize=16, y=0.95)

    # Display the plot
    plt.show()

####################################
# HW3 - compare the motion parameter plots from this script to 
# the carpet plot below.  What is the relationship between large rotations and/or translations and the carpet plot
# reference specific TRs and their relation to time.
####################################

# %%
from nilearn.plotting import plot_carpet

from nilearn import masking

# Build an EPI-based mask because we have no anatomical data

####################################
# HW3 - compare different func files and their carpet plots
# which one are we looking at here? Which func file has the 
# most visually striking motion related changes in voxel intensity?
####################################

mask_img = masking.compute_epi_mask(func_files[0])

display = plot_carpet(
    func_files[0],
    mask_img,
    t_r=1.76,
    standardize="zscore_sample",
    title="global patterns over time",
)

display.show()
